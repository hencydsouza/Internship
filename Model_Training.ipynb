# %%
#connect google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ls '/content/drive/MyDrive/Downloads/Plant_leave_diseases_dataset_with_augmentation'

# %%
# !unzip '/content/drive/MyDrive/Downloads/archive.zip' -d '/content/drive/MyDrive/Downloads/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import os
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical
from keras.models import load_model

# %%
print(tf.__version__)
# Out:
# 2.13.0

# %%
#plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = '/content/drive/MyDrive/Downloads/Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab'
for i in range(1,17):
  plt.subplot(4,4,i)
  plt.tight_layout()
  rand_img = imread(path+'/'+random.choice(sorted(os.listdir(path))))
  plt.imshow(rand_img)
  plt.xlabel(rand_img.shape[1], fontsize = 10) #width
  plt.ylabel(rand_img.shape[0], fontsize = 10) #height

# %%
#images to array
def convert_image_to_array(image_dir):
  try:
    image = cv2.imread(image_dir)
    if image is not None:
      image = cv2.resize(image, (256,256))
      return img_to_array(image)
    else:
      return np.array([])
  except Exception as e:
    print(f"Error : {e}")
    return None

# %%
dir = '/content/drive/MyDrive/Downloads/Plant_leave_diseases_dataset_with_augmentation'
image_list, label_list = [],[]
# all_labels = [folder for folder in os.listdir(dir) if os.path.isdir(os.path.join(dir, folder))][:3]
all_labels = ['Apple___healthy','Apple___Black_rot','Apple___Apple_scab']
print(all_labels)
binary_labels = []
for i in range(len(all_labels)):
  binary_labels.append(i)
print(binary_labels)
temp = -1

for directory in all_labels:
  plat_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plat_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])
# Out:
# ['Apple___healthy', 'Apple___Black_rot', 'Apple___Apple_scab']
# [0, 1, 2]

# %%
#Visualize the number of classes count
# label_counts = pd.DataFrame(label_list).value_counts()
# label_counts.head()

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2,random_state = 10)

# %%
x_train = np.array(x_train,dtype = np.float16) / 255.0
x_test = np.array(x_test,dtype=np.float16)/255.0
x_train = x_train.reshape(-1,256,256,3)
x_test = x_test.reshape(-1,256,256,3)

# %%
#one hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
#creating the model architecture, compile model and then fit it using the training data
model = Sequential()
model.add(Conv2D(32,(3,3), padding="same",input_shape=(256,256,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Conv2D(16,(3,3), padding="same",activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(8,activation="relu"))
model.add(Dense(len(all_labels),activation="softmax"))
model.summary()

# %%
model.compile(loss = 'categorical_crossentropy',optimizer=Adam(0.0001),metrics=['accuracy'])

# %%
# splitting the training data set into training and validation data sets
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.2,random_state=10)

# %%
#training the model
epochs = 50
batch_size = 128
history = model.fit(x_train,y_train,batch_size=batch_size,epochs = epochs,validation_data = (x_val,y_val))
# Out:
# Epoch 1/50
# 19/19 [==============================] - 19s 317ms/step - loss: 1.0658 - accuracy: 0.4391 - val_loss: 1.0516 - val_accuracy: 0.4332
# Epoch 2/50
# 19/19 [==============================] - 3s 134ms/step - loss: 1.0245 - accuracy: 0.4653 - val_loss: 1.0043 - val_accuracy: 0.5873
# Epoch 3/50
# 19/19 [==============================] - 3s 148ms/step - loss: 0.9765 - accuracy: 0.5463 - val_loss: 0.9330 - val_accuracy: 0.5890
# Epoch 4/50
# 19/19 [==============================] - 3s 175ms/step - loss: 0.8972 - accuracy: 0.5840 - val_loss: 0.8624 - val_accuracy: 0.6318
# Epoch 5/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.8345 - accuracy: 0.6093 - val_loss: 0.8050 - val_accuracy: 0.6318
# Epoch 6/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.7838 - accuracy: 0.6214 - val_loss: 0.7623 - val_accuracy: 0.6490
# Epoch 7/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.7415 - accuracy: 0.6407 - val_loss: 0.7265 - val_accuracy: 0.6473
# Epoch 8/50
# 19/19 [==============================] - 3s 154ms/step - loss: 0.7048 - accuracy: 0.6707 - val_loss: 0.6970 - val_accuracy: 0.6866
# Epoch 9/50
# 19/19 [==============================] - 3s 167ms/step - loss: 0.6804 - accuracy: 0.6994 - val_loss: 0.6742 - val_accuracy: 0.6952
# Epoch 10/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.6577 - accuracy: 0.7273 - val_loss: 0.6542 - val_accuracy: 0.7192
# Epoch 11/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.6433 - accuracy: 0.7474 - val_loss: 0.6401 - val_accuracy: 0.7586
# Epoch 12/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.6281 - accuracy: 0.7680 - val_loss: 0.6357 - val_accuracy: 0.7979
# Epoch 13/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.6139 - accuracy: 0.7809 - val_loss: 0.6194 - val_accuracy: 0.7517
# Epoch 14/50
# 19/19 [==============================] - 3s 161ms/step - loss: 0.5967 - accuracy: 0.7916 - val_loss: 0.6134 - val_accuracy: 0.7671
# Epoch 15/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.6011 - accuracy: 0.7916 - val_loss: 0.6299 - val_accuracy: 0.7260
# Epoch 16/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.5873 - accuracy: 0.8045 - val_loss: 0.5870 - val_accuracy: 0.7774
# Epoch 17/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.5793 - accuracy: 0.8002 - val_loss: 0.5942 - val_accuracy: 0.8065
# Epoch 18/50
# 19/19 [==============================] - 3s 156ms/step - loss: 0.5740 - accuracy: 0.8238 - val_loss: 0.5824 - val_accuracy: 0.7723
# Epoch 19/50
# 19/19 [==============================] - 3s 169ms/step - loss: 0.5559 - accuracy: 0.8242 - val_loss: 0.5645 - val_accuracy: 0.8202
# Epoch 20/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.5508 - accuracy: 0.8366 - val_loss: 0.5683 - val_accuracy: 0.7825
# Epoch 21/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.5407 - accuracy: 0.8383 - val_loss: 0.5496 - val_accuracy: 0.8271
# Epoch 22/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.5378 - accuracy: 0.8431 - val_loss: 0.5432 - val_accuracy: 0.8236
# Epoch 23/50
# 19/19 [==============================] - 3s 153ms/step - loss: 0.5293 - accuracy: 0.8482 - val_loss: 0.5470 - val_accuracy: 0.8425
# Epoch 24/50
# 19/19 [==============================] - 3s 156ms/step - loss: 0.5328 - accuracy: 0.8555 - val_loss: 0.5699 - val_accuracy: 0.7928
# Epoch 25/50
# 19/19 [==============================] - 3s 150ms/step - loss: 0.5397 - accuracy: 0.8229 - val_loss: 0.5373 - val_accuracy: 0.8425
# Epoch 26/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.5416 - accuracy: 0.8452 - val_loss: 0.5248 - val_accuracy: 0.8373
# Epoch 27/50
# 19/19 [==============================] - 3s 150ms/step - loss: 0.5100 - accuracy: 0.8585 - val_loss: 0.5600 - val_accuracy: 0.7962
# Epoch 28/50
# 19/19 [==============================] - 3s 164ms/step - loss: 0.5113 - accuracy: 0.8508 - val_loss: 0.5176 - val_accuracy: 0.8356
# Epoch 29/50
# 19/19 [==============================] - 3s 167ms/step - loss: 0.5032 - accuracy: 0.8581 - val_loss: 0.5111 - val_accuracy: 0.8510
# Epoch 30/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.4961 - accuracy: 0.8701 - val_loss: 0.5112 - val_accuracy: 0.8493
# Epoch 31/50
# 19/19 [==============================] - 3s 150ms/step - loss: 0.4903 - accuracy: 0.8645 - val_loss: 0.5107 - val_accuracy: 0.8527
# Epoch 32/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.5008 - accuracy: 0.8658 - val_loss: 0.5466 - val_accuracy: 0.7911
# Epoch 33/50
# 19/19 [==============================] - 3s 176ms/step - loss: 0.4923 - accuracy: 0.8636 - val_loss: 0.4978 - val_accuracy: 0.8527
# Epoch 34/50
# 19/19 [==============================] - 3s 138ms/step - loss: 0.4816 - accuracy: 0.8761 - val_loss: 0.5022 - val_accuracy: 0.8510
# Epoch 35/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.4794 - accuracy: 0.8816 - val_loss: 0.4913 - val_accuracy: 0.8562
# Epoch 36/50
# 19/19 [==============================] - 3s 150ms/step - loss: 0.4717 - accuracy: 0.8765 - val_loss: 0.4899 - val_accuracy: 0.8784
# Epoch 37/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.4713 - accuracy: 0.8774 - val_loss: 0.5017 - val_accuracy: 0.8527
# Epoch 38/50
# 19/19 [==============================] - 3s 169ms/step - loss: 0.4669 - accuracy: 0.8868 - val_loss: 0.4870 - val_accuracy: 0.8459
# Epoch 39/50
# 19/19 [==============================] - 3s 150ms/step - loss: 0.4625 - accuracy: 0.8855 - val_loss: 0.4854 - val_accuracy: 0.8613
# Epoch 40/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.4617 - accuracy: 0.8855 - val_loss: 0.4965 - val_accuracy: 0.8493
# Epoch 41/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.4592 - accuracy: 0.8855 - val_loss: 0.4749 - val_accuracy: 0.8750
# Epoch 42/50
# 19/19 [==============================] - 3s 155ms/step - loss: 0.4545 - accuracy: 0.8846 - val_loss: 0.4801 - val_accuracy: 0.8630
# Epoch 43/50
# 19/19 [==============================] - 3s 175ms/step - loss: 0.4538 - accuracy: 0.8915 - val_loss: 0.4796 - val_accuracy: 0.8613
# Epoch 44/50
# 19/19 [==============================] - 3s 151ms/step - loss: 0.4510 - accuracy: 0.8937 - val_loss: 0.4876 - val_accuracy: 0.8510
# Epoch 45/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.4493 - accuracy: 0.8872 - val_loss: 0.4724 - val_accuracy: 0.8733
# Epoch 46/50
# 19/19 [==============================] - 3s 137ms/step - loss: 0.4508 - accuracy: 0.9014 - val_loss: 0.4656 - val_accuracy: 0.8887
# Epoch 47/50
# 19/19 [==============================] - 3s 157ms/step - loss: 0.4392 - accuracy: 0.8962 - val_loss: 0.4659 - val_accuracy: 0.8784
# Epoch 48/50
# 19/19 [==============================] - 3s 155ms/step - loss: 0.4444 - accuracy: 0.9035 - val_loss: 0.4704 - val_accuracy: 0.8836
# Epoch 49/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.4398 - accuracy: 0.8954 - val_loss: 0.4585 - val_accuracy: 0.8870
# Epoch 50/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.4348 - accuracy: 0.9001 - val_loss: 0.4571 - val_accuracy: 0.8767

# %%
# model.save("/content/drive/MyDrive/Downloads/model-leaf-2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# model = load_model('/content/drive/MyDrive/Downloads/model.h5')

# %%
#plot the training history
plt.figure(figsize=(12,5))
plt.plot(history.history['accuracy'],color='r')
plt.plot(history.history['val_accuracy'],color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','val'])

plt.show()

# %%
print('Calculating model accuracy')
scores = model.evaluate(x_test,y_test)
print(f"Test Accuract: {scores[1]*100}")
# Out:
# Calculating model accuracy
# 23/23 [==============================] - 1s 26ms/step - loss: 0.4315 - accuracy: 0.8957
# Test Accuract: 89.57476019859314

# %%
#making predictions on testing data
y_pred = model.predict(x_test)
# Out:
# 23/23 [==============================] - 1s 18ms/step

# %%
#visualizing the original and predicted labels for the test images
#plotting image to compare
img = array_to_img(x_test[4])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
#finding max value from predicted list and comparing original values vs predicted
print("Original Label: ",all_labels[np.argmax(y_test[4])])
print("Predicted Label: ",all_labels[np.argmax(y_pred[4])])
print(y_pred[4])
# Out:
# Original Label:  Apple___Black_rot
# Predicted Label:  Apple___Black_rot
# [0.31101495 0.3736603  0.31532475]

# %%
for i in range(50):
  print(all_labels[np.argmax(y_test[i])],"-",all_labels[np.argmax(y_pred[i])])
# Out:
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___Black_rot - Apple___Black_rot
# Apple___Apple_scab - Apple___Apple_scab
# Apple___Black_rot - Apple___Black_rot
# Apple___Apple_scab - Apple___Apple_scab
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___healthy
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___healthy
# Apple___Apple_scab - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___Apple_scab
# Apple___Apple_scab - Apple___Apple_scab
# Apple___Black_rot - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___Apple_scab
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Black_rot - Apple___Black_rot
# Apple___Apple_scab - Apple___Apple_scab
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___Apple_scab
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___Apple_scab
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___healthy - Apple___healthy
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___Black_rot - Apple___Black_rot
# Apple___healthy - Apple___healthy
# Apple___Apple_scab - Apple___Apple_scab
# Apple___Black_rot - Apple___Black_rot
